# %%
import pandas as pd

df = pd.read_csv("data.csv")

print("Dataset:")
print(df)

print("\nMissing values in each column:")
print(df.isnull().sum())

print("\nNon-missing values in each column:")
print(df.notnull().sum())
# Out:
# Dataset:
#    ID     Name   Age  Gender Department   Salary  Year  Sales
# 0   1    Alice  25.0       F         HR  30000.0  2020    200
# 1   2      Bob  30.0       M         IT  45000.0  2021    250
# 2   3  Charlie   NaN    male    Finance  50000.0  2022    300
# 3   4    David  28.0       M         IT      NaN  2021    280
# 4   5      Eva  35.0  Female         HR  60000.0  2020    220
# 5   6    Frank  40.0       M    Finance  75000.0  2022    350
# 6   7    Grace  29.0  female         IT  48000.0  2023    400
# 7   8    Helen   NaN       F         HR  52000.0  2023    420
# 8   9      Ian  32.0       M    Finance  58000.0  2021    260
# 9  10     Jane  27.0  Female        NaN  47000.0  2020    210
#
# Missing values in each column:
# ID            0
# Name          0
# Age           2
# Gender        0
# Department    1
# Salary        1
# Year          0
# Sales         0
# dtype: int64
#
# Non-missing values in each column:
# ID            10
# Name          10
# Age            8
# Gender        10
# Department     9
# Salary         9
# Year          10
# Sales         10
# dtype: int64
