# %%
import pandas as pd

df = pd.read_csv("data.csv")

# fill numeric columns
df["Age"] = df["Age"].fillna(df["Age"].mean())

# fill categorical column
df["Department"] = df["Department"].fillna("Unknown")

print("Dataset after filling missing values:")
print(df)
# Out:
# Dataset after filling missing values:
#    ID     Name    Age  Gender Department   Salary  Year  Sales
# 0   1    Alice  25.00       F         HR  30000.0  2020    200
# 1   2      Bob  30.00       M         IT  45000.0  2021    250
# 2   3  Charlie  30.75    male    Finance  50000.0  2022    300
# 3   4    David  28.00       M         IT      NaN  2021    280
# 4   5      Eva  35.00  Female         HR  60000.0  2020    220
# 5   6    Frank  40.00       M    Finance  75000.0  2022    350
# 6   7    Grace  29.00  female         IT  48000.0  2023    400
# 7   8    Helen  30.75       F         HR  52000.0  2023    420
# 8   9      Ian  32.00       M    Finance  58000.0  2021    260
# 9  10     Jane  27.00  Female    Unknown  47000.0  2020    210
